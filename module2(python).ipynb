# %%
# Theoretical Assignments:
''' 1.Explain Python’s Role in Data Science
    Python’s Role in Data Science :

Python is widely used in data science because it is simple, powerful, and has many libraries for working with data.

Main roles:

Data Collection – Gather data from websites, APIs, or databases.

Data Cleaning – Prepare and organize raw data using tools like Pandas and NumPy.

Data Analysis – Find patterns and insights in data.

Data Visualization – Create charts and graphs using Matplotlib.

Machine Learning – Build predictive models using Scikit-learn.

In short: Python helps data scientists collect, process, analyze, visualize, and build models from data. '''
# Out:
# ' 1.Explain Python’s Role in Data Science\n    Python’s Role in Data Science :\n\nPython is widely used in data science because it is simple, powerful, and has many libraries for working with data.\n\nMain roles:\n\nData Collection – Gather data from websites, APIs, or databases.\n\nData Cleaning – Prepare and organize raw data using tools like Pandas and NumPy.\n\nData Analysis – Find patterns and insights in data.\n\nData Visualization – Create charts and graphs using Matplotlib.\n\nMachine Learning – Build predictive models using Scikit-learn.\n\nIn short: Python helps data scientists collect, process, analyze, visualize, and build models from data. '

# %%
'''2. Presentation: Object-Oriented Programming (OOP) Concepts in Python

 1. Introduction

Python supports Object-Oriented Programming (OOP), which organizes code using objects and classes.
OOP makes programs modular, reusable, and easier to maintain.

2. Class and Object

Class: Blueprint for creating objects.

Object: Instance of a class.

Example:

class Car:
    def __init__(self, brand):
        self.brand = brand

car1 = Car("Toyota")
print(car1.brand)
3. Encapsulation

Encapsulation means hiding data and controlling access to it using methods.

Example:

class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

Benefits:

Data protection

Controlled access

4. Inheritance

Inheritance allows a class to inherit properties and methods from another class.

Example:

class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    pass

Benefits:

Code reuse

Reduced duplication

5. Polymorphism

Polymorphism means same method name but different behavior.

Example:

class Bird:
    def sound(self):
        print("Bird sound")

class Cat:
    def sound(self):
        print("Meow")
6. Abstraction

Abstraction means showing only essential features and hiding implementation details.

Example:

from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
7. Advantages of OOP

Code reusability

Better organization

Easier maintenance

Improved scalability

 Conclusion
OOP in Python helps developers build structured, reusable, and efficient programs using concepts like Encapsulation, Inheritance, Polymorphism, and Abstraction. '''

# %%
# Practical task
# 1.Write a python program to sum of the first n positive integers.
a= int(input("Enter a number: "))
n=0
for i in range(a+1):
    n+=i
print(n)
# Out:
# 6

# %%
#2.Write a Python program to count occurrences of a substring in a string.
string = input("Enter the main string: ")
substring = input("Enter the substring to count: ")

count = string.count(substring)

print("Occurrences of substring:", count)
# Out:
# Occurrences of substring: 3

# %%
#3. Write a Python program to count the occurrences of each word in a given sentence
sentence = input("Enter a sentence: ")

words = sentence.split()
word_count = {}

for word in words:
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1

print("Word occurrences:")
for word, count in word_count.items():
    print(word, ":", count)
# Out:
# Word occurrences:
# python : 2
# is : 2
# easy : 1
# and : 1
# powerful : 1
